# %%
import osmnx as ox
from IPython.display import Image
# %matplotlib inline
ox.config(log_file=True, log_console=True, use_cache=True)

# %%
# configure the inline image display
img_folder = 'images'
extension = 'png'
size = 600
# size = 350
dpi = 90

# %%
place = 'nyc'
point = (40.757920, -73.983393)
fig, ax = ox.plot_figure_ground(point=point, filename=place, dpi=dpi)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
place = 'nyc'
point = (40.757920, -73.983393)
fig, ax = ox.plot_figure_ground(point=point, filename=place, dpi=dpi)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
place = 'rome'
point = (41.901336, 12.471831)
fig, ax = ox.plot_figure_ground(point=point, filename=place, network_type='all', default_width=3.3, dpi=dpi)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
# 31.217849, 121.457571
place = 'shanghai'
point = (31.234696, 121.481170)
fig, ax = ox.plot_figure_ground(point=point, filename=place, network_type='all', dpi=dpi)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
#40.082049, 116.346082 回龙观
place = 'beijing_huilongguan'
point = (40.082049, 116.346082)
fig, ax = ox.plot_figure_ground(point=point, filename=place, network_type='all', dpi=dpi)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
#23.116849, 113.330676 广州猎德
place = 'guangzhou'
point = (23.128151, 113.337933)
fig, ax = ox.plot_figure_ground(point=point, filename=place, network_type='all', dpi=dpi)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)

# %%
#30.257988, 120.180509
place = 'hangzhou'
point = (30.257988, 120.180509)
fig, ax = ox.plot_figure_ground(point=point, filename=place, network_type='all', dpi=dpi)
Image('{}/{}.{}'.format(img_folder, place, extension), height=size, width=size)
