# %%
from sklearn import datasets
from sklearn.cross_validation import train_test_split, cross_val_score
from sklearn.neighbors import KNeighborsClassifier

# %%
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# ### 1常规过程

# %% [markdown]
# train_test_split

# %%
#create train and test env
X_train,X_test, y_train,y_test = train_test_split(X,y,random_state = 4,)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
# pred_knn = knn.predict(X_test)
print(knn.score(X_test,y_test))
# Out:
# 0.973684210526

# %% [markdown]
# ### 2 交叉验证

# %% [markdown]
# cross_val_score

# %%
knn = KNeighborsClassifier(n_neighbors=5)
scores = cross_val_score(knn, X,y,cv=5, scoring='accuracy')

# %%
print(scores)
# print(\n)
print(scores.mean())
# Out:
# [ 0.96666667  1.          0.93333333  0.96666667  1.        ]
# 0.973333333333

# %% [markdown]
# ### 3 参数调优

# %% [markdown]
# 注意部分模型选用最大化accuracy，部分模型选用最小化mean_squared_error

# %%
import matplotlib.pyplot as plt

# %%
k_range = range(1,31)
knn_scores = []

# %%
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X,y, cv=10, scoring='accuracy')
    knn_scores.append(scores.mean())

# %%
#plot parameter and score
plt.figure()
plt.plot(k_range, knn_scores)
plt.xlabel('Parameter n_neihbors')
plt.ylabel('accuracy score')
plt.show()

# %%
knn_loss = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    loss = - cross_val_score(knn, X,y,cv=10,scoring='neg_mean_squared_error')
    knn_loss.append(loss.mean())

# %%
#plot parameter and loss
plt.figure()
plt.plot(k_range, knn_loss)
plt.xlabel('Parameter n_neihbors')
plt.ylabel('neg mean squared error')
plt.show()
