# %% [markdown]
# # Word2Vec Model

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
from gensim.test.utils import datapath
from gensim import utils

class MyCorpus:
    """An iterator that yields sentences (lists of str)."""

    def __iter__(self):
        corpus_path = datapath('lee_background.cor')
        for line in open(corpus_path):
            # assume there's one document per line, tokens separated by whitespace
            yield utils.simple_preprocess(line)
# Out:
# 2021-02-08 15:10:26,445 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2021-02-08 15:10:26,446 : INFO : built Dictionary(12 unique tokens: ['computer', 'human', 'interface', 'response', 'survey']...) from 9 documents (total 29 corpus positions)

# %%
import gensim.models

sentences = MyCorpus()
model = gensim.models.Word2Vec(sentences=sentences)
# Out:
# 2021-02-08 15:10:43,333 : INFO : collecting all words and their counts
# 2021-02-08 15:10:43,336 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2021-02-08 15:10:43,416 : INFO : collected 6981 word types from a corpus of 58152 raw words and 300 sentences
# 2021-02-08 15:10:43,417 : INFO : Loading a fresh vocabulary
# 2021-02-08 15:10:43,421 : INFO : effective_min_count=5 retains 1750 unique words (25% of original 6981, drops 5231)
# 2021-02-08 15:10:43,422 : INFO : effective_min_count=5 leaves 49335 word corpus (84% of original 58152, drops 8817)
# 2021-02-08 15:10:43,426 : INFO : deleting the raw counts dictionary of 6981 items
# 2021-02-08 15:10:43,427 : INFO : sample=0.001 downsamples 51 most-common words
# 2021-02-08 15:10:43,427 : INFO : downsampling leaves estimated 35935 word corpus (72.8% of prior 49335)
# 2021-02-08 15:10:43,430 : INFO : estimated required memory for 1750 words and 100 dimensions: 2275000 bytes
# 2021-02-08 15:10:43,431 : INFO : resetting layer weights
# 2021-02-08 15:10:43,717 : INFO : training model with 3 workers on 1750 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=5
# 2021-02-08 15:10:43,802 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-08 15:10:43,806 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-08 15:10:43,808 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-08 15:10:43,809 : INFO : EPOCH - 1 : training on 58152 raw words (35865 effective words) took 0.1s, 403390 effective words/s
# 2021-02-08 15:10:43,896 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-08 15:10:43,897 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-08 15:10:43,900 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-08 15:10:43,900 : INFO : EPOCH - 2 : training on 58152 raw words (35870 effective words) took 0.1s, 401679 effective words/s
# 2021-02-08 15:10:43,980 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-08 15:10:43,984 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-08 15:10:43,986 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-08 15:10:43,986 : INFO : EPOCH - 3 : training on 58152 raw words (35874 effective words) took 0.1s, 423481 effective words/s
# 2021-02-08 15:10:44,065 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-08 15:10:44,068 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-08 15:10:44,069 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-08 15:10:44,070 : INFO : EPOCH - 4 : training on 58152 raw words (35925 effective words) took 0.1s, 439609 effective words/s
# 2021-02-08 15:10:44,150 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2021-02-08 15:10:44,152 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2021-02-08 15:10:44,156 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2021-02-08 15:10:44,156 : INFO : EPOCH - 5 : training on 58152 raw words (35926 effective words) took 0.1s, 422397 effective words/s
# 2021-02-08 15:10:44,156 : INFO : training on a 290760 raw words (179460 effective words) took 0.4s, 409025 effective words/s

# %%
model.wv.index2word
# Out:
# ['the',
#  'to',
#  'of',
#  'in',
#  'and',
#  'he',
#  'is',
#  'for',
#  'on',
#  'said',
#  'that',
#  'has',
#  'says',
#  'was',
#  'have',
#  'it',
#  'be',
#  'are',
#  'with',
#  'will',
#  'at',
#  'mr',
#  'from',
#  'by',
#  'we',
#  'been',
#  'as',
#  'an',
#  'not',
#  'his',
#  'but',
#  'they',
#  'after',
#  'were',
#  'had',
#  'there',
#  'new',
#  'this',
#  'australia',
#  'australian',
#  'who',
#  'people',
#  'palestinian',
#  'their',
#  'two',
#  'government',
#  'up',
#  'south',
#  'us',
#  'which',
#  'year',
#  'one',
#  'about',
#  'out',
#  'if',
#  'also',
#  'more',
#  'when',
#  'its',
#  'would',
#  'into',
#  'first',
#  'against',
#  'last',
#  'israeli',
#  'minister',
#  'arafat',
#  'all',
#  'over',
#  'three',
#  'afghanistan',
#  'united',
#  'no',
#  'world',
#  'police',
#  'or',
#  'than',
#  'fire',
#  'before',
#  'attacks',
#  'some',
#  'security',
#  'day',
#  'states',
#  'you',
#  'could',
#  'them',
#  'today',
#  'say',
#  'now',
#  'told',
#  'time',
#  'any',
#  'very',
#  'laden',
#  'just',
#  'bin',
#  'can',
#  'sydney',
#  'still',
#  'president',
#  'what',
#  'company',
#  'four',
#  'man',
#  'taliban',
#  'killed',
#  'forces',
#  'our',
#  'al',
#  'around',
#  'west',
#  'days',
#  'being',
#  'old',
#  'other',
#  'so',
#  'where',
#  'officials',
#  'test',
#  'qaeda',
#  'israel',
#  'next',
#  'federal',
#  'think',
#  'general',
#  'per',
#  'she',
#  'force',
#  'cent',
#  'yesterday',
#  'leader',
#  'workers',
#  'state',
#  'take',
#  'him',
#  'under',
#  'hamas',
#  'those',
#  'years',
#  'meeting',
#  'back',
#  'suicide',
#  'bank',
#  'action',
#  'made',
#  'down',
#  'morning',
#  'commission',
#  'pakistan',
#  'international',
#  're',
#  'attack',
#  'city',
#  'group',
#  'afghan',
#  'centre',
#  'while',
#  'military',
#  'well',
#  'through',
#  'number',
#  'members',
#  'called',
#  'area',
#  'five',
#  'local',
#  'qantas',
#  'national',
#  'week',
#  'union',
#  'gaza',
#  'wales',
#  'since',
#  'hours',
#  'including',
#  'september',
#  'east',
#  'another',
#  'north',
#  'night',
#  'should',
#  'off',
#  'report',
#  'between',
#  'war',
#  'six',
#  'staff',
#  'these',
#  'get',
#  'second',
#  'go',
#  'earlier',
#  'end',
#  'further',
#  'do',
#  'months',
#  'islamic',
#  'defence',
#  'near',
#  'areas',
#  'because',
#  'foreign',
#  'work',
#  'power',
#  'team',
#  'going',
#  'authority',
#  'sharon',
#  'eight',
#  'india',
#  'died',
#  'only',
#  'during',
#  'know',
#  'many',
#  'way',
#  'month',
#  'make',
#  'left',
#  've',
#  'northern',
#  'claims',
#  'spokesman',
#  'match',
#  'melbourne',
#  'good',
#  'metres',
#  'former',
#  'air',
#  'authorities',
#  'support',
#  'most',
#  'peace',
#  'like',
#  'prime',
#  'osama',
#  'ago',
#  'am',
#  'set',
#  'expected',
#  'given',
#  'saying',
#  'militants',
#  'place',
#  'put',
#  'come',
#  'looking',
#  'tora',
#  'bora',
#  'fighters',
#  'several',
#  'children',
#  'meanwhile',
#  'indian',
#  'arrested',
#  'groups',
#  'troops',
#  'christmas',
#  'river',
#  'royal',
#  'injured',
#  'africa',
#  'found',
#  'child',
#  'unions',
#  'interim',
#  'hospital',
#  'then',
#  'official',
#  'part',
#  'talks',
#  'terrorist',
#  'yasser',
#  'whether',
#  'reports',
#  'mountains',
#  'senior',
#  'how',
#  'start',
#  'third',
#  'early',
#  'terrorism',
#  'don',
#  'leaders',
#  'statement',
#  'industrial',
#  'economy',
#  'weather',
#  'both',
#  'million',
#  'public',
#  'trying',
#  'army',
#  'hit',
#  'court',
#  'believe',
#  'radio',
#  'john',
#  'pay',
#  'family',
#  'long',
#  'chief',
#  'following',
#  'lead',
#  'however',
#  'control',
#  'asked',
#  'agreement',
#  'dr',
#  'best',
#  'pressure',
#  'help',
#  'adelaide',
#  'service',
#  'few',
#  'firefighters',
#  'queensland',
#  'better',
#  'process',
#  'play',
#  'want',
#  'overnight',
#  'high',
#  'house',
#  'taken',
#  'community',
#  'close',
#  'need',
#  'arrest',
#  'services',
#  'does',
#  'confirmed',
#  'australians',
#  'labor',
#  'came',
#  'detainees',
#  'won',
#  'williams',
#  'secretary',
#  'information',
#  'believed',
#  'must',
#  'opposition',
#  'much',
#  'shot',
#  'took',
#  'accused',
#  'win',
#  'her',
#  'brought',
#  'nations',
#  'british',
#  'possible',
#  'peter',
#  'released',
#  'did',
#  'party',
#  'damage',
#  'held',
#  'governor',
#  'pentagon',
#  'maintenance',
#  'hicks',
#  'winds',
#  'hill',
#  'across',
#  'conditions',
#  'dead',
#  'asylum',
#  'return',
#  'got',
#  'even',
#  'despite',
#  'lot',
#  'cut',
#  'armed',
#  'eastern',
#  'without',
#  'director',
#  'change',
#  'such',
#  'airline',
#  'safety',
#  'weekend',
#  'violence',
#  'building',
#  'council',
#  'york',
#  'kandahar',
#  'southern',
#  'strong',
#  'fires',
#  'far',
#  'december',
#  'economic',
#  'too',
#  'role',
#  'seekers',
#  'home',
#  'aircraft',
#  'here',
#  'american',
#  'continuing',
#  'working',
#  'strip',
#  'palestinians',
#  'race',
#  'see',
#  'country',
#  'region',
#  'monday',
#  'david',
#  'board',
#  'emergency',
#  'crew',
#  'call',
#  'men',
#  'trade',
#  'waugh',
#  'lee',
#  'news',
#  'cricket',
#  'anti',
#  'fighting',
#  'training',
#  'captured',
#  'bureau',
#  'act',
#  'key',
#  'health',
#  'used',
#  'received',
#  'offer',
#  'charged',
#  'zinni',
#  'administration',
#  'rate',
#  'water',
#  'head',
#  'past',
#  'george',
#  'bush',
#  'plans',
#  'alliance',
#  'industry',
#  'hundreds',
#  'town',
#  'decision',
#  'parliament',
#  'use',
#  'within',
#  'risk',
#  'downer',
#  'major',
#  'britain',
#  'operations',
#  'department',
#  'final',
#  'line',
#  'least',
#  'known',
#  'large',
#  'person',
#  'israelis',
#  'stop',
#  'boat',
#  'captain',
#  'zealand',
#  'leading',
#  'may',
#  'your',
#  'soldiers',
#  'airport',
#  'legal',
#  'issue',
#  'strikes',
#  'hih',
#  'station',
#  'homes',
#  'pm',
#  'coast',
#  'western',
#  'remain',
#  'series',
#  'able',
#  'kabul',
#  'give',
#  'great',
#  'my',
#  'taking',
#  'position',
#  'every',
#  'death',
#  'might',
#  'due',
#  'laws',
#  'plane',
#  'officers',
#  'half',
#  'behind',
#  'later',
#  'late',
#  'shane',
#  'ahead',
#  'network',
#  'tomorrow',
#  'weapons',
#  'right',
#  'hollingworth',
#  'policy',
#  'un',
#  'interest',
#  'latest',
#  'forced',
#  'towards',
#  'storm',
#  'really',
#  'concerned',
#  'deaths',
#  'along',
#  'seen',
#  'same',
#  'territory',
#  'jobs',
#  'failed',
#  'victory',
#  'cup',
#  'event',
#  'hard',
#  'others',
#  'continue',
#  'me',
#  'already',
#  'point',
#  'campaign',
#  'flight',
#  'side',
#  'washington',
#  'jihad',
#  'life',
#  'thought',
#  'abuse',
#  'heard',
#  'timor',
#  'bill',
#  'special',
#  'guilty',
#  'details',
#  'capital',
#  'likely',
#  'launched',
#  'matter',
#  'countries',
#  'th',
#  'hour',
#  'buildings',
#  'move',
#  'sunday',
#  'situation',
#  'weeks',
#  'again',
#  'seven',
#  'mark',
#  'enough',
#  'envoy',
#  'november',
#  'according',
#  'case',
#  'bichel',
#  'innings',
#  'mcgrath',
#  'member',
#  'helicopters',
#  'bombing',
#  'important',
#  'bowler',
#  'cabinet',
#  'warne',
#  'bombings',
#  'woomera',
#  'detention',
#  'middle',
#  'space',
#  'bus',
#  'canyoning',
#  'rates',
#  'top',
#  'aedt',
#  'blue',
#  'based',
#  'raids',
#  'political',
#  'office',
#  'women',
#  'claimed',
#  'perth',
#  'swiss',
#  'wants',
#  'dispute',
#  'opened',
#  'reported',
#  'african',
#  'forward',
#  'boy',
#  'jail',
#  'disease',
#  'show',
#  'human',
#  'carried',
#  'mission',
#  'movement',
#  'added',
#  'sure',
#  'caught',
#  'run',
#  'immediately',
#  'rule',
#  'cancer',
#  'money',
#  'justice',
#  'ms',
#  'warplanes',
#  'young',
#  'freeze',
#  'deal',
#  'evidence',
#  'own',
#  'commonwealth',
#  'targets',
#  'asio',
#  'adventure',
#  'guides',
#  'burning',
#  'probably',
#  'carrying',
#  'border',
#  'each',
#  'march',
#  'investigation',
#  'island',
#  'using',
#  'beat',
#  'access',
#  'prepared',
#  'face',
#  'always',
#  'times',
#  'order',
#  'become',
#  'banks',
#  'crash',
#  'planning',
#  'ground',
#  'break',
#  'certainly',
#  'result',
#  'job',
#  'wicket',
#  'although',
#  'flying',
#  'find',
#  'financial',
#  'full',
#  'reached',
#  'allegations',
#  'sector',
#  'collapse',
#  'proposed',
#  'growth',
#  'stage',
#  'suspected',
#  'militant',
#  'road',
#  'argentina',
#  'until',
#  'executive',
#  'tried',
#  'immigration',
#  'future',
#  'fight',
#  'opening',
#  'quickly',
#  'kilometres',
#  'thursday',
#  'getting',
#  'drop',
#  'thousands',
#  'trees',
#  'energy',
#  'inside',
#  'sent',
#  'short',
#  'inquiry',
#  'allow',
#  'soon',
#  'post',
#  'killing',
#  'radical',
#  'hewitt',
#  'himself',
#  'flights',
#  'tourists',
#  'clear',
#  'calls',
#  'sex',
#  'organisation',
#  'serious',
#  'lives',
#  'comes',
#  'went',
#  'bowling',
#  'wave',
#  'ansett',
#  'travel',
#  'needs',
#  'surrender',
#  'militia',
#  'believes',
#  'caves',
#  'bid',
#  'rejected',
#  'ariel',
#  'declared',
#  'making',
#  'alleged',
#  'howard',
#  'responsibility',
#  'program',
#  'relations',
#  'outside',
#  'afp',
#  'senator',
#  'management',
#  'different',
#  'reserve',
#  'harrison',
#  'residents',
#  'rural',
#  'available',
#  'parts',
#  'done',
#  'quite',
#  'announced',
#  'victoria',
#  'alexander',
#  'refused',
#  'yet',
#  'currently',
#  'try',
#  'means',
#  'brisbane',
#  'destroyed',
#  'measures',
#  'parties',
#  'among',
#  'meet',
#  'warned',
#  'form',
#  'ended',
#  'jewish',
#  'sources',
#  'gunmen',
#  'yacht',
#  'nine',
#  'open',
#  'list',
#  'biggest',
#  'something',
#  'happened',
#  'increase',
#  'decided',
#  'changes',
#  'terms',
#  'figures',
#  'rise',
#  'sea',
#  'source',
#  'kallis',
#  'wickets',
#  'running',
#  'donald',
#  'television',
#  'attempt',
#  'tanks',
#  'returned',
#  'circumstances',
#  'annual',
#  'wounded',
#  'fighter',
#  'look',
#  'rights',
#  'shortly',
#  'karzai',
#  'school',
#  'understand',
#  'ministers',
#  'witnesses',
#  'agency',
#  'white',
#  'response',
#  'bombers',
#  'accident',
#  'actually',
#  'july',
#  'issues',
#  'anything',
#  'offices',
#  'ruddock',
#  'sentence',
#  'directors',
#  'address',
#  'huge',
#  'highway',
#  'caused',
#  'less',
#  'fact',
#  'intelligence',
#  'period',
#  'recession',
#  'worst',
#  'involved',
#  'll',
#  'pacific',
#  'nauru',
#  'total',
#  'tennis',
#  'though',
#  'afternoon',
#  'friday',
#  'commissioner',
#  'struck',
#  'car',
#  'began',
#  'musharraf',
#  'gives',
#  'appeared',
#  'commanders',
#  'hobart',
#  'away',
#  'tour',
#  'ever',
#  'blake',
#  'crowd',
#  'airlines',
#  'powell',
#  'confidence',
#  'supporters',
#  'difficult',
#  'ensure',
#  'prevent',
#  'media',
#  'runs',
#  'field',
#  'allan',
#  'glenn',
#  'rafter',
#  'big',
#  'arrived',
#  'beginning',
#  'market',
#  'business',
#  'sir',
#  'having',
#  'expect',
#  'expressed',
#  'beyond',
#  'cost',
#  'commander',
#  'deputy',
#  'law',
#  'step',
#  'advice',
#  'gave',
#  'followed',
#  'facility',
#  'bomb',
#  'robert',
#  'strike',
#  'rather',
#  'attorney',
#  'whose',
#  'negotiations',
#  'elected',
#  'wage',
#  'suharto',
#  'islands',
#  'virus',
#  'ses',
#  'longer',
#  'places',
#  'significant',
#  'pakistani',
#  'organisations',
#  'level',
#  'tasmania',
#  'crisis',
#  'massive',
#  'debt',
#  'plan',
#  'labour',
#  'threat',
#  'finished',
#  'france',
#  'americans',
#  'chance',
#  'game',
#  'protect',
#  'smoke',
#  'storms',
#  'entered',
#  'themselves',
#  'saturday',
#  'conflict',
#  'giving',
#  'geoff',
#  'sort',
#  'front',
#  'explosives',
#  'fast',
#  'lost',
#  'never',
#  'round',
#  'reid',
#  'placed',
#  'calling',
#  'anthony',
#  'bring',
#  'played',
#  'feel',
#  'survey',
#  'cannot',
#  'potential',
#  'complex',
#  'speaking',
#  'boxing',
#  'jacques',
#  'brett',
#  'nearly',
#  'helicopter',
#  'muslim',
#  'base',
#  'main',
#  'endeavour',
#  'heavy',
#  'jenin',
#  'yes',
#  'population',
#  'changed',
#  'terror',
#  'russian',
#  'macgill',
#  'anglican',
#  'criticism',
#  'crean',
#  'employees',
#  'assistance',
#  'powers',
#  'son',
#  'zimbabwe',
#  'vote',
#  'current',
#  'hearings',
#  'daryl',
#  'entitlements',
#  'decide',
#  'chairman',
#  'together',
#  'quarter',
#  'trip',
#  'indonesia',
#  'ballot',
#  'conference',
#  'costs',
#  'denied',
#  'ambush',
#  'martin',
#  'lockett',
#  'tragedy',
#  'study',
#  'moved',
#  'closed',
#  'rain',
#  'little',
#  'efforts',
#  'sides',
#  'recorded',
#  'nation',
#  'fellow',
#  'tony',
#  'environment',
#  'hold',
#  'fleeing',
#  'anyone',
#  'severe',
#  'forecast',
#  'coming',
#  'greater',
#  'activity',
#  'cars',
#  ...]

# %%
vec_king = model.wv['king']
wv = model.wv
for index, word in enumerate(wv.index2word):
    if index == 10:
        break
    print(f"word #{index}/{len(wv.index2word)} is {word}")
# Out:
# word #0/1750 is the
# word #1/1750 is to
# word #2/1750 is of
# word #3/1750 is in
# word #4/1750 is and
# word #5/1750 is he
# word #6/1750 is is
# word #7/1750 is for
# word #8/1750 is on
# word #9/1750 is said

# %%
vec_king.shape
# Out:
# (100,)

# %% [markdown]
# ### evaluating

# %%
model.wv.evaluate_word_analogies(datapath('questions-words.txt'))
# Out:
# 2021-02-08 15:27:21,864 : INFO : Evaluating word analogies for top 300000 words in the model on /Users/wegzheng/.pyenv/versions/3.7.9/lib/python3.7/site-packages/gensim/test/test_data/questions-words.txt
# 2021-02-08 15:27:21,868 : INFO : precomputing L2-norms of word weight vectors
# 2021-02-08 15:27:21,875 : INFO : capital-common-countries: 0.0% (0/6)
# 2021-02-08 15:27:21,890 : INFO : capital-world: 0.0% (0/2)
# 2021-02-08 15:27:21,906 : INFO : family: 0.0% (0/6)
# 2021-02-08 15:27:21,921 : INFO : gram3-comparative: 0.0% (0/20)
# 2021-02-08 15:27:21,927 : INFO : gram4-superlative: 0.0% (0/12)
# 2021-02-08 15:27:21,935 : INFO : gram5-present-participle: 0.0% (0/20)
# 2021-02-08 15:27:21,944 : INFO : gram6-nationality-adjective: 0.0% (0/30)
# 2021-02-08 15:27:21,954 : INFO : gram7-past-tense: 0.0% (0/20)
# 2021-02-08 15:27:21,962 : INFO : gram8-plural: 0.0% (0/30)
# 2021-02-08 15:27:21,966 : INFO : Quadruplets with out-of-vocabulary words: 99.3%
# 2021-02-08 15:27:21,967 : INFO : NB: analogies containing OOV words were skipped from evaluation! To change this behavior, use "dummy4unknown=True"
# 2021-02-08 15:27:21,968 : INFO : Total accuracy: 0.0% (0/146)
# (0.0,
#  [{'section': 'capital-common-countries',
#    'correct': [],
#    'incorrect': [('CANBERRA', 'AUSTRALIA', 'KABUL', 'AFGHANISTAN'),
#     ('CANBERRA', 'AUSTRALIA', 'PARIS', 'FRANCE'),
#     ('KABUL', 'AFGHANISTAN', 'PARIS', 'FRANCE'),
#     ('KABUL', 'AFGHANISTAN', 'CANBERRA', 'AUSTRALIA'),
#     ('PARIS', 'FRANCE', 'CANBERRA', 'AUSTRALIA'),
#     ('PARIS', 'FRANCE', 'KABUL', 'AFGHANISTAN')]},
#   {'section': 'capital-world',
#    'correct': [],
#    'incorrect': [('CANBERRA', 'AUSTRALIA', 'KABUL', 'AFGHANISTAN'),
#     ('KABUL', 'AFGHANISTAN', 'PARIS', 'FRANCE')]},
#   {'section': 'currency', 'correct': [], 'incorrect': []},
#   {'section': 'city-in-state', 'correct': [], 'incorrect': []},
#   {'section': 'family',
#    'correct': [],
#    'incorrect': [('HE', 'SHE', 'HIS', 'HER'),
#     ('HE', 'SHE', 'MAN', 'WOMAN'),
#     ('HIS', 'HER', 'MAN', 'WOMAN'),
#     ('HIS', 'HER', 'HE', 'SHE'),
#     ('MAN', 'WOMAN', 'HE', 'SHE'),
#     ('MAN', 'WOMAN', 'HIS', 'HER')]},
#   {'section': 'gram1-adjective-to-adverb', 'correct': [], 'incorrect': []},
#   {'section': 'gram2-opposite', 'correct': [], 'incorrect': []},
#   {'section': 'gram3-comparative',
#    'correct': [],
#    'incorrect': [('GOOD', 'BETTER', 'GREAT', 'GREATER'),
#     ('GOOD', 'BETTER', 'LONG', 'LONGER'),
#     ('GOOD', 'BETTER', 'LOW', 'LOWER'),
#     ('GOOD', 'BETTER', 'SMALL', 'SMALLER'),
#     ('GREAT', 'GREATER', 'LONG', 'LONGER'),
#     ('GREAT', 'GREATER', 'LOW', 'LOWER'),
#     ('GREAT', 'GREATER', 'SMALL', 'SMALLER'),
#     ('GREAT', 'GREATER', 'GOOD', 'BETTER'),
#     ('LONG', 'LONGER', 'LOW', 'LOWER'),
#     ('LONG', 'LONGER', 'SMALL', 'SMALLER'),
#     ('LONG', 'LONGER', 'GOOD', 'BETTER'),
#     ('LONG', 'LONGER', 'GREAT', 'GREATER'),
#     ('LOW', 'LOWER', 'SMALL', 'SMALLER'),
#     ('LOW', 'LOWER', 'GOOD', 'BETTER'),
#     ('LOW', 'LOWER', 'GREAT', 'GREATER'),
#     ('LOW', 'LOWER', 'LONG', 'LONGER'),
#     ('SMALL', 'SMALLER', 'GOOD', 'BETTER'),
#     ('SMALL', 'SMALLER', 'GREAT', 'GREATER'),
#     ('SMALL', 'SMALLER', 'LONG', 'LONGER'),
#     ('SMALL', 'SMALLER', 'LOW', 'LOWER')]},
#   {'section': 'gram4-superlative',
#    'correct': [],
#    'incorrect': [('BIG', 'BIGGEST', 'GOOD', 'BEST'),
#     ('BIG', 'BIGGEST', 'GREAT', 'GREATEST'),
#     ('BIG', 'BIGGEST', 'LARGE', 'LARGEST'),
#     ('GOOD', 'BEST', 'GREAT', 'GREATEST'),
#     ('GOOD', 'BEST', 'LARGE', 'LARGEST'),
#     ('GOOD', 'BEST', 'BIG', 'BIGGEST'),
#     ('GREAT', 'GREATEST', 'LARGE', 'LARGEST'),
#     ('GREAT', 'GREATEST', 'BIG', 'BIGGEST'),
#     ('GREAT', 'GREATEST', 'GOOD', 'BEST'),
#     ('LARGE', 'LARGEST', 'BIG', 'BIGGEST'),
#     ('LARGE', 'LARGEST', 'GOOD', 'BEST'),
#     ('LARGE', 'LARGEST', 'GREAT', 'GREATEST')]},
#   {'section': 'gram5-present-participle',
#    'correct': [],
#    'incorrect': [('GO', 'GOING', 'LOOK', 'LOOKING'),
#     ('GO', 'GOING', 'PLAY', 'PLAYING'),
#     ('GO', 'GOING', 'RUN', 'RUNNING'),
#     ('GO', 'GOING', 'SAY', 'SAYING'),
#     ('LOOK', 'LOOKING', 'PLAY', 'PLAYING'),
#     ('LOOK', 'LOOKING', 'RUN', 'RUNNING'),
#     ('LOOK', 'LOOKING', 'SAY', 'SAYING'),
#     ('LOOK', 'LOOKING', 'GO', 'GOING'),
#     ('PLAY', 'PLAYING', 'RUN', 'RUNNING'),
#     ('PLAY', 'PLAYING', 'SAY', 'SAYING'),
#     ('PLAY', 'PLAYING', 'GO', 'GOING'),
#     ('PLAY', 'PLAYING', 'LOOK', 'LOOKING'),
#     ('RUN', 'RUNNING', 'SAY', 'SAYING'),
#     ('RUN', 'RUNNING', 'GO', 'GOING'),
#     ('RUN', 'RUNNING', 'LOOK', 'LOOKING'),
#     ('RUN', 'RUNNING', 'PLAY', 'PLAYING'),
#     ('SAY', 'SAYING', 'GO', 'GOING'),
#     ('SAY', 'SAYING', 'LOOK', 'LOOKING'),
#     ('SAY', 'SAYING', 'PLAY', 'PLAYING'),
#     ('SAY', 'SAYING', 'RUN', 'RUNNING')]},
#   {'section': 'gram6-nationality-adjective',
#    'correct': [],
#    'incorrect': [('AUSTRALIA', 'AUSTRALIAN', 'FRANCE', 'FRENCH'),
#     ('AUSTRALIA', 'AUSTRALIAN', 'INDIA', 'INDIAN'),
#     ('AUSTRALIA', 'AUSTRALIAN', 'ISRAEL', 'ISRAELI'),
#     ('AUSTRALIA', 'AUSTRALIAN', 'JAPAN', 'JAPANESE'),
#     ('AUSTRALIA', 'AUSTRALIAN', 'SWITZERLAND', 'SWISS'),
#     ('FRANCE', 'FRENCH', 'INDIA', 'INDIAN'),
#     ('FRANCE', 'FRENCH', 'ISRAEL', 'ISRAELI'),
#     ('FRANCE', 'FRENCH', 'JAPAN', 'JAPANESE'),
#     ('FRANCE', 'FRENCH', 'SWITZERLAND', 'SWISS'),
#     ('FRANCE', 'FRENCH', 'AUSTRALIA', 'AUSTRALIAN'),
#     ('INDIA', 'INDIAN', 'ISRAEL', 'ISRAELI'),
#     ('INDIA', 'INDIAN', 'JAPAN', 'JAPANESE'),
#     ('INDIA', 'INDIAN', 'SWITZERLAND', 'SWISS'),
#     ('INDIA', 'INDIAN', 'AUSTRALIA', 'AUSTRALIAN'),
#     ('INDIA', 'INDIAN', 'FRANCE', 'FRENCH'),
#     ('ISRAEL', 'ISRAELI', 'JAPAN', 'JAPANESE'),
#     ('ISRAEL', 'ISRAELI', 'SWITZERLAND', 'SWISS'),
#     ('ISRAEL', 'ISRAELI', 'AUSTRALIA', 'AUSTRALIAN'),
#     ('ISRAEL', 'ISRAELI', 'FRANCE', 'FRENCH'),
#     ('ISRAEL', 'ISRAELI', 'INDIA', 'INDIAN'),
#     ('JAPAN', 'JAPANESE', 'SWITZERLAND', 'SWISS'),
#     ('JAPAN', 'JAPANESE', 'AUSTRALIA', 'AUSTRALIAN'),
#     ('JAPAN', 'JAPANESE', 'FRANCE', 'FRENCH'),
#     ('JAPAN', 'JAPANESE', 'INDIA', 'INDIAN'),
#     ('JAPAN', 'JAPANESE', 'ISRAEL', 'ISRAELI'),
#     ('SWITZERLAND', 'SWISS', 'AUSTRALIA', 'AUSTRALIAN'),
#     ('SWITZERLAND', 'SWISS', 'FRANCE', 'FRENCH'),
#     ('SWITZERLAND', 'SWISS', 'INDIA', 'INDIAN'),
#     ('SWITZERLAND', 'SWISS', 'ISRAEL', 'ISRAELI'),
#     ('SWITZERLAND', 'SWISS', 'JAPAN', 'JAPANESE')]},
#   {'section': 'gram7-past-tense',
#    'correct': [],
#    'incorrect': [('GOING', 'WENT', 'PAYING', 'PAID'),
#     ('GOING', 'WENT', 'PLAYING', 'PLAYED'),
#     ('GOING', 'WENT', 'SAYING', 'SAID'),
#     ('GOING', 'WENT', 'TAKING', 'TOOK'),
#     ('PAYING', 'PAID', 'PLAYING', 'PLAYED'),
#     ('PAYING', 'PAID', 'SAYING', 'SAID'),
#     ('PAYING', 'PAID', 'TAKING', 'TOOK'),
#     ('PAYING', 'PAID', 'GOING', 'WENT'),
#     ('PLAYING', 'PLAYED', 'SAYING', 'SAID'),
#     ('PLAYING', 'PLAYED', 'TAKING', 'TOOK'),
#     ('PLAYING', 'PLAYED', 'GOING', 'WENT'),
#     ('PLAYING', 'PLAYED', 'PAYING', 'PAID'),
#     ('SAYING', 'SAID', 'TAKING', 'TOOK'),
#     ('SAYING', 'SAID', 'GOING', 'WENT'),
#     ('SAYING', 'SAID', 'PAYING', 'PAID'),
#     ('SAYING', 'SAID', 'PLAYING', 'PLAYED'),
#     ('TAKING', 'TOOK', 'GOING', 'WENT'),
#     ('TAKING', 'TOOK', 'PAYING', 'PAID'),
#     ('TAKING', 'TOOK', 'PLAYING', 'PLAYED'),
#     ('TAKING', 'TOOK', 'SAYING', 'SAID')]},
#   {'section': 'gram8-plural',
#    'correct': [],
#    'incorrect': [('BUILDING', 'BUILDINGS', 'CAR', 'CARS'),
#     ('BUILDING', 'BUILDINGS', 'CHILD', 'CHILDREN'),
#     ('BUILDING', 'BUILDINGS', 'MAN', 'MEN'),
#     ('BUILDING', 'BUILDINGS', 'ROAD', 'ROADS'),
#     ('BUILDING', 'BUILDINGS', 'WOMAN', 'WOMEN'),
#     ('CAR', 'CARS', 'CHILD', 'CHILDREN'),
#     ('CAR', 'CARS', 'MAN', 'MEN'),
#     ('CAR', 'CARS', 'ROAD', 'ROADS'),
#     ('CAR', 'CARS', 'WOMAN', 'WOMEN'),
#     ('CAR', 'CARS', 'BUILDING', 'BUILDINGS'),
#     ('CHILD', 'CHILDREN', 'MAN', 'MEN'),
#     ('CHILD', 'CHILDREN', 'ROAD', 'ROADS'),
#     ('CHILD', 'CHILDREN', 'WOMAN', 'WOMEN'),
#     ('CHILD', 'CHILDREN', 'BUILDING', 'BUILDINGS'),
#     ('CHILD', 'CHILDREN', 'CAR', 'CARS'),
#     ('MAN', 'MEN', 'ROAD', 'ROADS'),
#     ('MAN', 'MEN', 'WOMAN', 'WOMEN'),
#     ('MAN', 'MEN', 'BUILDING', 'BUILDINGS'),
#     ('MAN', 'MEN', 'CAR', 'CARS'),
#     ('MAN', 'MEN', 'CHILD', 'CHILDREN'),
#     ('ROAD', 'ROADS', 'WOMAN', 'WOMEN'),
#     ('ROAD', 'ROADS', 'BUILDING', 'BUILDINGS'),
#     ('ROAD', 'ROADS', 'CAR', 'CARS'),
#     ('ROAD', 'ROADS', 'CHILD', 'CHILDREN'),
#     ('ROAD', 'ROADS', 'MAN', 'MEN'),
#     ('WOMAN', 'WOMEN', 'BUILDING', 'BUILDINGS'),
#     ('WOMAN', 'WOMEN', 'CAR', 'CARS'),
#     ('WOMAN', 'WOMEN', 'CHILD', 'CHILDREN'),
#     ('WOMAN', 'WOMEN', 'MAN', 'MEN'),
#     ('WOMAN', 'WOMEN', 'ROAD', 'ROADS')]},
#   {'section': 'gram9-plural-verbs', 'correct': [], 'incorrect': []},
#   {'section': 'Total accuracy',
#    'correct': [],
#    'incorrect': [('CANBERRA', 'AUSTRALIA', 'KABUL', 'AFGHANISTAN'),
#     ('CANBERRA', 'AUSTRALIA', 'PARIS', 'FRANCE'),
#     ('KABUL', 'AFGHANISTAN', 'PARIS', 'FRANCE'),
#     ('KABUL', 'AFGHANISTAN', 'CANBERRA', 'AUSTRALIA'),
#     ('PARIS', 'FRANCE', 'CANBERRA', 'AUSTRALIA'),
#     ('PARIS', 'FRANCE', 'KABUL', 'AFGHANISTAN'),
#     ('CANBERRA', 'AUSTRALIA', 'KABUL', 'AFGHANISTAN'),
#     ('KABUL', 'AFGHANISTAN', 'PARIS', 'FRANCE'),
#     ('HE', 'SHE', 'HIS', 'HER'),
#     ('HE', 'SHE', 'MAN', 'WOMAN'),
#     ('HIS', 'HER', 'MAN', 'WOMAN'),
#     ('HIS', 'HER', 'HE', 'SHE'),
#     ('MAN', 'WOMAN', 'HE', 'SHE'),
#     ('MAN', 'WOMAN', 'HIS', 'HER'),
#     ('GOOD', 'BETTER', 'GREAT', 'GREATER'),
#     ('GOOD', 'BETTER', 'LONG', 'LONGER'),
#     ('GOOD', 'BETTER', 'LOW', 'LOWER'),
#     ('GOOD', 'BETTER', 'SMALL', 'SMALLER'),
#     ('GREAT', 'GREATER', 'LONG', 'LONGER'),
#     ('GREAT', 'GREATER', 'LOW', 'LOWER'),
#     ('GREAT', 'GREATER', 'SMALL', 'SMALLER'),
#     ('GREAT', 'GREATER', 'GOOD', 'BETTER'),
#     ('LONG', 'LONGER', 'LOW', 'LOWER'),
#     ('LONG', 'LONGER', 'SMALL', 'SMALLER'),
#     ('LONG', 'LONGER', 'GOOD', 'BETTER'),
#     ('LONG', 'LONGER', 'GREAT', 'GREATER'),
#     ('LOW', 'LOWER', 'SMALL', 'SMALLER'),
#     ('LOW', 'LOWER', 'GOOD', 'BETTER'),
#     ('LOW', 'LOWER', 'GREAT', 'GREATER'),
#     ('LOW', 'LOWER', 'LONG', 'LONGER'),
#     ('SMALL', 'SMALLER', 'GOOD', 'BETTER'),
#     ('SMALL', 'SMALLER', 'GREAT', 'GREATER'),
#     ('SMALL', 'SMALLER', 'LONG', 'LONGER'),
#     ('SMALL', 'SMALLER', 'LOW', 'LOWER'),
#     ('BIG', 'BIGGEST', 'GOOD', 'BEST'),
#     ('BIG', 'BIGGEST', 'GREAT', 'GREATEST'),
#     ('BIG', 'BIGGEST', 'LARGE', 'LARGEST'),
#     ('GOOD', 'BEST', 'GREAT', 'GREATEST'),
#     ('GOOD', 'BEST', 'LARGE', 'LARGEST'),
#     ('GOOD', 'BEST', 'BIG', 'BIGGEST'),
#     ('GREAT', 'GREATEST', 'LARGE', 'LARGEST'),
#     ('GREAT', 'GREATEST', 'BIG', 'BIGGEST'),
#     ('GREAT', 'GREATEST', 'GOOD', 'BEST'),
#     ('LARGE', 'LARGEST', 'BIG', 'BIGGEST'),
#     ('LARGE', 'LARGEST', 'GOOD', 'BEST'),
#     ('LARGE', 'LARGEST', 'GREAT', 'GREATEST'),
#     ('GO', 'GOING', 'LOOK', 'LOOKING'),
#     ('GO', 'GOING', 'PLAY', 'PLAYING'),
#     ('GO', 'GOING', 'RUN', 'RUNNING'),
#     ('GO', 'GOING', 'SAY', 'SAYING'),
#     ('LOOK', 'LOOKING', 'PLAY', 'PLAYING'),
#     ('LOOK', 'LOOKING', 'RUN', 'RUNNING'),
#     ('LOOK', 'LOOKING', 'SAY', 'SAYING'),
#     ('LOOK', 'LOOKING', 'GO', 'GOING'),
#     ('PLAY', 'PLAYING', 'RUN', 'RUNNING'),
#     ('PLAY', 'PLAYING', 'SAY', 'SAYING'),
#     ('PLAY', 'PLAYING', 'GO', 'GOING'),
#     ('PLAY', 'PLAYING', 'LOOK', 'LOOKING'),
#     ('RUN', 'RUNNING', 'SAY', 'SAYING'),
#     ('RUN', 'RUNNING', 'GO', 'GOING'),
#     ('RUN', 'RUNNING', 'LOOK', 'LOOKING'),
#     ('RUN', 'RUNNING', 'PLAY', 'PLAYING'),
#     ('SAY', 'SAYING', 'GO', 'GOING'),
#     ('SAY', 'SAYING', 'LOOK', 'LOOKING'),
#     ('SAY', 'SAYING', 'PLAY', 'PLAYING'),
#     ('SAY', 'SAYING', 'RUN', 'RUNNING'),
#     ('AUSTRALIA', 'AUSTRALIAN', 'FRANCE', 'FRENCH'),
#     ('AUSTRALIA', 'AUSTRALIAN', 'INDIA', 'INDIAN'),
#     ('AUSTRALIA', 'AUSTRALIAN', 'ISRAEL', 'ISRAELI'),
#     ('AUSTRALIA', 'AUSTRALIAN', 'JAPAN', 'JAPANESE'),
#     ('AUSTRALIA', 'AUSTRALIAN', 'SWITZERLAND', 'SWISS'),
#     ('FRANCE', 'FRENCH', 'INDIA', 'INDIAN'),
#     ('FRANCE', 'FRENCH', 'ISRAEL', 'ISRAELI'),
#     ('FRANCE', 'FRENCH', 'JAPAN', 'JAPANESE'),
#     ('FRANCE', 'FRENCH', 'SWITZERLAND', 'SWISS'),
#     ('FRANCE', 'FRENCH', 'AUSTRALIA', 'AUSTRALIAN'),
#     ('INDIA', 'INDIAN', 'ISRAEL', 'ISRAELI'),
#     ('INDIA', 'INDIAN', 'JAPAN', 'JAPANESE'),
#     ('INDIA', 'INDIAN', 'SWITZERLAND', 'SWISS'),
#     ('INDIA', 'INDIAN', 'AUSTRALIA', 'AUSTRALIAN'),
#     ('INDIA', 'INDIAN', 'FRANCE', 'FRENCH'),
#     ('ISRAEL', 'ISRAELI', 'JAPAN', 'JAPANESE'),
#     ('ISRAEL', 'ISRAELI', 'SWITZERLAND', 'SWISS'),
#     ('ISRAEL', 'ISRAELI', 'AUSTRALIA', 'AUSTRALIAN'),
#     ('ISRAEL', 'ISRAELI', 'FRANCE', 'FRENCH'),
#     ('ISRAEL', 'ISRAELI', 'INDIA', 'INDIAN'),
#     ('JAPAN', 'JAPANESE', 'SWITZERLAND', 'SWISS'),
#     ('JAPAN', 'JAPANESE', 'AUSTRALIA', 'AUSTRALIAN'),
#     ('JAPAN', 'JAPANESE', 'FRANCE', 'FRENCH'),
#     ('JAPAN', 'JAPANESE', 'INDIA', 'INDIAN'),
#     ('JAPAN', 'JAPANESE', 'ISRAEL', 'ISRAELI'),
#     ('SWITZERLAND', 'SWISS', 'AUSTRALIA', 'AUSTRALIAN'),
#     ('SWITZERLAND', 'SWISS', 'FRANCE', 'FRENCH'),
#     ('SWITZERLAND', 'SWISS', 'INDIA', 'INDIAN'),
#     ('SWITZERLAND', 'SWISS', 'ISRAEL', 'ISRAELI'),
#     ('SWITZERLAND', 'SWISS', 'JAPAN', 'JAPANESE'),
#     ('GOING', 'WENT', 'PAYING', 'PAID'),
#     ('GOING', 'WENT', 'PLAYING', 'PLAYED'),
#     ('GOING', 'WENT', 'SAYING', 'SAID'),
#     ('GOING', 'WENT', 'TAKING', 'TOOK'),
#     ('PAYING', 'PAID', 'PLAYING', 'PLAYED'),
#     ('PAYING', 'PAID', 'SAYING', 'SAID'),
#     ('PAYING', 'PAID', 'TAKING', 'TOOK'),
#     ('PAYING', 'PAID', 'GOING', 'WENT'),
#     ('PLAYING', 'PLAYED', 'SAYING', 'SAID'),
#     ('PLAYING', 'PLAYED', 'TAKING', 'TOOK'),
#     ('PLAYING', 'PLAYED', 'GOING', 'WENT'),
#     ('PLAYING', 'PLAYED', 'PAYING', 'PAID'),
#     ('SAYING', 'SAID', 'TAKING', 'TOOK'),
#     ('SAYING', 'SAID', 'GOING', 'WENT'),
#     ('SAYING', 'SAID', 'PAYING', 'PAID'),
#     ('SAYING', 'SAID', 'PLAYING', 'PLAYED'),
#     ('TAKING', 'TOOK', 'GOING', 'WENT'),
#     ('TAKING', 'TOOK', 'PAYING', 'PAID'),
#     ('TAKING', 'TOOK', 'PLAYING', 'PLAYED'),
#     ('TAKING', 'TOOK', 'SAYING', 'SAID'),
#     ('BUILDING', 'BUILDINGS', 'CAR', 'CARS'),
#     ('BUILDING', 'BUILDINGS', 'CHILD', 'CHILDREN'),
#     ('BUILDING', 'BUILDINGS', 'MAN', 'MEN'),
#     ('BUILDING', 'BUILDINGS', 'ROAD', 'ROADS'),
#     ('BUILDING', 'BUILDINGS', 'WOMAN', 'WOMEN'),
#     ('CAR', 'CARS', 'CHILD', 'CHILDREN'),
#     ('CAR', 'CARS', 'MAN', 'MEN'),
#     ('CAR', 'CARS', 'ROAD', 'ROADS'),
#     ('CAR', 'CARS', 'WOMAN', 'WOMEN'),
#     ('CAR', 'CARS', 'BUILDING', 'BUILDINGS'),
#     ('CHILD', 'CHILDREN', 'MAN', 'MEN'),
#     ('CHILD', 'CHILDREN', 'ROAD', 'ROADS'),
#     ('CHILD', 'CHILDREN', 'WOMAN', 'WOMEN'),
#     ('CHILD', 'CHILDREN', 'BUILDING', 'BUILDINGS'),
#     ('CHILD', 'CHILDREN', 'CAR', 'CARS'),
#     ('MAN', 'MEN', 'ROAD', 'ROADS'),
#     ('MAN', 'MEN', 'WOMAN', 'WOMEN'),
#     ('MAN', 'MEN', 'BUILDING', 'BUILDINGS'),
#     ('MAN', 'MEN', 'CAR', 'CARS'),
#     ('MAN', 'MEN', 'CHILD', 'CHILDREN'),
#     ('ROAD', 'ROADS', 'WOMAN', 'WOMEN'),
#     ('ROAD', 'ROADS', 'BUILDING', 'BUILDINGS'),
#     ('ROAD', 'ROADS', 'CAR', 'CARS'),
#     ('ROAD', 'ROADS', 'CHILD', 'CHILDREN'),
#     ('ROAD', 'ROADS', 'MAN', 'MEN'),
#     ('WOMAN', 'WOMEN', 'BUILDING', 'BUILDINGS'),
#     ('WOMAN', 'WOMEN', 'CAR', 'CARS'),
#     ('WOMAN', 'WOMEN', 'CHILD', 'CHILDREN'),
#     ('WOMAN', 'WOMEN', 'MAN', 'MEN'),
#     ('WOMAN', 'WOMEN', 'ROAD', 'ROADS')]}])

# %%
model.wv.evaluate_word_pairs(datapath('wordsim353.tsv'))
# Out:
# 2021-02-08 15:28:56,949 : INFO : Pearson correlation coefficient against /Users/wegzheng/.pyenv/versions/3.7.9/lib/python3.7/site-packages/gensim/test/test_data/wordsim353.tsv: 0.1991
# 2021-02-08 15:28:56,950 : INFO : Spearman rank-order correlation coefficient against /Users/wegzheng/.pyenv/versions/3.7.9/lib/python3.7/site-packages/gensim/test/test_data/wordsim353.tsv: 0.1414
# 2021-02-08 15:28:56,950 : INFO : Pairs with unknown words ratio: 83.0%
# ((0.19906543384391617, 0.12730312889605422),
#  SpearmanrResult(correlation=0.14142003699985478, pvalue=0.281114353497797),
#  83.0028328611898)
