# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g =sns.FacetGrid(tips, col = 'sex', row = 'smoker')
g= g.map(plt.scatter, 'total_bill', 'tip').set(xlabel = 'US dollars')

# %%
import sys

# %%
reload(sys)
sys.setdefaultencoding('utf8')

# %%
sns.set_style("ticks",{"font.sans-serif":['Microsoft YaHei', 'Arial']})

g =sns.FacetGrid(tips, col = 'sex', row = 'smoker', size = 5)
g= g.map(plt.scatter, 'total_bill', 'tip').set(xlabel = '美金')

# %%
g =sns.lmplot(data = tips, x = 'total_bill', y = 'tip', hue = 'time', fit_reg = False).set(xlabel = '账单($)', ylabel = '小费($)')
# g.savefig('figures/sns_scatter.png', dpi = 300)

# %%
sns.axes_style()
# Out:
# {'axes.axisbelow': True,
#  'axes.edgecolor': '.15',
#  'axes.facecolor': 'white',
#  'axes.grid': False,
#  'axes.labelcolor': '.15',
#  'axes.linewidth': 1.25,
#  'figure.facecolor': 'white',
#  'font.family': [u'sans-serif'],
#  'font.sans-serif': [u'Microsoft YaHei', u'Arial'],
#  'grid.color': '.8',
#  'grid.linestyle': u'-',
#  'image.cmap': u'Greys',
#  'legend.frameon': False,
#  'legend.numpoints': 1,
#  'legend.scatterpoints': 1,
#  'lines.solid_capstyle': u'round',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'xtick.direction': u'out',
#  'xtick.major.size': 6.0,
#  'xtick.minor.size': 3.0,
#  'ytick.color': '.15',
#  'ytick.direction': u'out',
#  'ytick.major.size': 6.0,
#  'ytick.minor.size': 3.0}

# %%
sns.set_style('darkgrid')
sns.distplot(tips['total_bill'], bins =20, color = 'g',  kde = True)
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
