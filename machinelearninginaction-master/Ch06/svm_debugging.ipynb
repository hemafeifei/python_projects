# %%
import svmMLiA_3

# %%
data_arr, label_arr = svmMLiA_3.load_dataset('testSet.txt')

# %%
label_arr[:3]
# Out:
# [-1.0, -1.0, 1.0]

# %%
data_arr[:3]
# Out:
# [[3.542485, 1.977398], [3.018896, 2.556416], [7.55151, -1.58003]]

# %% [markdown]
# #### Test 大函数

# %%
from imp import reload

# %%
reload(svmMLiA_3)
# Out:
# <module 'svmMLiA_3' from '/Users/weizheng/PycharmProjects/python_projects/machinelearninginaction-master/Ch06/svmMLiA_3.py'>

# %%
b, alphas = svmMLiA_3.smo_simple(data_arr, label_arr, 0.6, 0.001, 40)
# Out:
# L==H
# L==H
# iter 0 i: 2, pairs changed 1
# iter 0 i: 3, pairs changed 2
# iter 0 i: 4, pairs changed 3
# iter 0 i: 5, pairs changed 4
# iter 0 i: 7, pairs changed 5
# iter 0 i: 8, pairs changed 6
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# L==H
# iter 0 i: 25, pairs changed 7
# iter 0 i: 26, pairs changed 8
# iter 0 i: 27, pairs changed 9
# L==H
# L==H
# L==H
# iter 0 i: 46, pairs changed 10
# iter 0 i: 52, pairs changed 11
# iter 0 i: 54, pairs changed 12
# iter 0 i: 55, pairs changed 13
# iter 0 i: 65, pairs changed 14
# L==H
# L==H
# L==H
# L==H
# L==H
# iteration number: 0
# L==H
# j not moving enough
# iter 0 i: 3, pairs changed 1
# iter 0 i: 4, pairs changed 2
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# L==H
# j not moving enough
# j not moving enough
# j not moving enough
# ...

# %%
b
# Out:
# matrix([[-2.20140201]])

# %%
alphas[alphas>0]
# Out:
# matrix([[ 0.05311411,  0.0355054 ,  0.00408629,  0.00333652,  0.00720394,
#           0.01782758,  0.00421154,  0.00376967,  0.00798121,  0.0050614 ,
#           0.0050614 ,  0.02537056,  0.02572027,  0.05109082]])

# %%
for i in range(100):
    if alphas[i] > 0.0:
        print(data_arr[i], label_arr[i])
# Out:
# [7.55151, -1.58003] 1.0
# [2.114999, -0.004466] -1.0
# [8.127113, 1.274372] 1.0
# [7.108772, -0.986906] 1.0
# [2.326297, 0.265213] -1.0
# [3.634009, 1.730537] -1.0
# [7.40786, -0.121961] 1.0
# [7.286357, 0.251077] 1.0
# [2.301095, -0.533988] -1.0
# [6.960661, -0.245353] 1.0
# [2.893743, -1.643468] -1.0
# [5.286862, -2.358286] 1.0
# [6.080573, 0.418886] 1.0
# [2.529893, 0.662657] -1.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(data_arr)

# %%
fig = plt.figure()
plt.scatter(df[df.columns[0]], df[df.columns[1]], c=label_arr)
plt.show();

# %%
np.mat(data_arr).shape
# Out:
# (100, 2)

# %%
data_arr[:,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-497aa962f322> in <module>()
# ----> 1 data_arr[:,0]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
for i in range(100):
    if alphas[i] > 0.0:
        plt.scatter(data_arr[i][0], data_arr[i][1], c='y')
